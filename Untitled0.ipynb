# %% [markdown]
# <a href="https://colab.research.google.com/github/AshleySouza/LOJA-CARROS/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
dados = {
    "ID": [1, 2, 3, 4, 5],
    "Nome": ["Ana", "Bruno", "Carlos", "Daniela", "Eduardo"],
    "Idade": [22, 35, 28, 31, 26],
    "Cidade": ["São Paulo", "Rio de Janeiro", "Belo Horizonte","Curitiba", "Salvador"],
    "Cargo": ["Analista", "Desenvolvedor", "DBA", "Suporte", "Gerente"],
    "Salario": [3500, 5200, 4800, 3000, 7000]
}
data = pd.DataFrame(dados)
data
# Out:
#    ID     Nome  Idade          Cidade          Cargo  Salario
# 0   1      Ana     22       São Paulo       Analista     3500
# 1   2    Bruno     35  Rio de Janeiro  Desenvolvedor     5200
# 2   3   Carlos     28  Belo Horizonte            DBA     4800
# 3   4  Daniela     31        Curitiba        Suporte     3000
# 4   5  Eduardo     26        Salvador        Gerente     7000

# %%
soma = np.sum(data["Salario"])
soma
# Out:
# np.int64(23500)

# %%
soma = np.sum(data["Salario"])
med = np.median(data["Salario"])
med
# Out:
# np.float64(4800.0)

# %%
maior = np.max(data["Salario"])
maior
# Out:
# 7000

# %%
menor = np.min(data["Salario"])
menor
# Out:
# 3000
